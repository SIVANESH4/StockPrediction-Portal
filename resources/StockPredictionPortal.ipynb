# %%
import pandas as pd

# %%
df = pd.read_csv("call_activity.csv")
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
dictdf = {
    "Name": ['John', 'Mike', 'Bob'],
    "Desg": ['SDE', 'Desginer', 'CEO'],
    "salary": [100000, 80000, 200000]
}

# %%
tempdf = pd.DataFrame.from_dict(dictdf)

# %%
tempdf
# Out:
#    Name      Desg  salary
# 0  John       SDE  100000
# 1  Mike  Desginer   80000
# 2   Bob       CEO  200000

# %%
tempdf.columns
# Out:
# Index(['Name', 'Desg', 'salary'], dtype='str')

# %%
tempdf.dtypes
# Out:
# Name        str
# Desg        str
# salary    int64
# dtype: object

# %%
tempdf.Name
# Out:
# 0    John
# 1    Mike
# 2     Bob
# Name: Name, dtype: str

# %%
df[('Name', 'Desg')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\stockenv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: ('Name', 'Desg')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df[('Name', 'Desg')]
#
# File ~\.conda\envs\stockenv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
# ...

# %%
tempdf[['Name', 'Desg']]
# Out:
#    Name      Desg
# 0  John       SDE
# 1  Mike  Desginer
# 2   Bob       CEO

# %%
tempdf[tempdf['Name'] == 'John']
# Out:
#    Name Desg  salary
# 0  John  SDE  100000

# %%
df[df['State'] == 'NJ']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2       NJ             137        415                 No              No
# 39      NJ             149        408                 No              No
# 70      NJ             138        408                 No              No
# 89      NJ             128        415                 No              No
# 116     NJ              64        510                 No              No
# ...    ...             ...        ...                ...             ...
# 3034    NJ              75        415                 No             Yes
# 3126    NJ             108        415                 No              No
# 3136    NJ             107        408                 No             Yes
# 3248    NJ              93        415                 No              No
# 3279    NJ             139        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[(df['State'] == 'NJ') & (df['Voice mail plan'] == 'Yes')]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 527     NJ              95        415                 No             Yes
# 626     NJ              95        408                Yes             Yes
# 633     NJ             122        415                 No             Yes
# 693     NJ              92        510                 No             Yes
# 734     NJ              93        415                Yes             Yes
# 910     NJ              42        415                 No             Yes
# 966     NJ              48        510                 No             Yes
# 1105    NJ             135        510                 No             Yes
# 1409    NJ               1        415                 No             Yes
# 1479    NJ              66        415                 No             Yes
# 1802    NJ             147        415                 No             Yes
# 1903    NJ              93        510                Yes             Yes
# ...

# %%
df.iloc(15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\stockenv\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     523             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     524         except KeyError as err:
# --> 525             raise ValueError(
#     526                 f"No axis named {axis} for object type {cls.__name__}"
#
# KeyError: 15
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15400\1642065072.py in ?()
# ----> 1 df.iloc(15)
#
# ~\.conda\envs\stockenv\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     762         # we need to return a copy of ourselves
#     763         new_self = type(self)(self.name, self.obj)
#     764
#     765         if axis is not None:
# ...

# %%
df.iloc[15]
# Out:
# State                        NY
# Account length              161
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         317.8
# Total eve calls            97.0
# Total eve charge          27.01
# Total night minutes       160.6
# Total night calls         128.0
# Total night charge         7.23
# Total intl minutes          5.4
# Total intl calls              9
# Total intl charge          1.46
# Customer service calls      4.0
# Churn                      True
# Name: 15, dtype: object

# %%
df.iloc[15,4]
# Out:
# 'No'

# %%
df.iloc[15, 11]
# Out:
# np.float64(27.01)

# %%
df.iloc[15:25]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 15    NY             161        415                 No              No
# 16    ID              85        408                 No             Yes
# 17    VT              93        510                 No              No
# 18    VA              76        510                 No             Yes
# 19    TX              73        415                 No              No
# 20    FL             147        415                 No              No
# 21    CO              77        408                 No              No
# 22    AZ             130        415                 No              No
# 23    SC             111        415                 No              No
# 24    VA             132        510                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 15                      0                NaN              NaN
# ...

# %%
state = df.copy()

# %%
state.set_index('State', inplace = True)

# %%
state.loc['NJ']
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# NJ                137        415                 No              No
# NJ                149        408                 No              No
# NJ                138        408                 No              No
# NJ                128        415                 No              No
# NJ                 64        510                 No              No
# ...               ...        ...                ...             ...
# NJ                 75        415                 No             Yes
# NJ                108        415                 No              No
# NJ                107        408                 No             Yes
# NJ                 93        415                 No              No
# NJ                139        415                 No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# NJ                         0              243.4            114.0
# ...

# %%
state.reset_index()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.isnull()
# Out:
#       State  Account length  Area code  International plan  Voice mail plan  \
# 0     False           False      False               False            False
# 1     False           False      False               False            False
# 2     False           False      False               False            False
# 3     False           False      False               False            False
# 4     False           False      False               False            False
# ...     ...             ...        ...                 ...              ...
# 3328  False           False      False               False            False
# 3329  False           False      False               False            False
# 3330  False           False      False               False            False
# 3331  False           False      False               False            False
# 3332  False           False      False               False            False
#
# ...

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.columns.isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.drop('Churn', axis=1)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df['Total charge'] = df['Total day charge'] + df['Total night charge']

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.iloc[0,-1] = 70

# %%
df.iloc[0,-1]
# Out:
# np.float64(70.0)

# %%
df.iloc[0]
# Out:
# State                        KS
# Account length              128
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        25
# Total day minutes         265.1
# Total day calls           110.0
# Total day charge          45.07
# Total eve minutes         197.4
# Total eve calls            99.0
# Total eve charge          16.78
# Total night minutes       244.7
# Total night calls          91.0
# Total night charge        11.01
# Total intl minutes         10.0
# Total intl calls              3
# Total intl charge           2.7
# Customer service calls      1.0
# Churn                     False
# Total charge               70.0
# Name: 0, dtype: object

# %%
df.to_json('output.json')
