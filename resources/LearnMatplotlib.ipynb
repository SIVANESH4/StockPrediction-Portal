# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a = np.random.randint(1,100,10)

# %%
b = np.random.randint(1,50,10)

# %%
c = [1,2,3,4,5]

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\SIVANESH\\.conda\\envs\\stockenv\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.plot(c, 'b', a, label='Marks');

# %%
plt.plot(c, 'r', b, label="
